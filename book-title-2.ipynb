# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_book_titles.csv")

print(df.shape)

df.head()
# Out:
# (52316, 3)
#                                        Title           Author Rating
# 0                           The Hunger Games  Suzanne Collins   4.33
# 1  Harry Potter and the Order of the Phoenix     J.K. Rowling   4.50
# 2                      To Kill a Mockingbird       Harper Lee   4.28
# 3                        Pride and Prejudice      Jane Austen   4.26
# 4                                   Twilight  Stephenie Meyer   3.59

# %%
df.head(20)
# Out:
#                                                 Title             Author  \
# 0                                    The Hunger Games    Suzanne Collins
# 1           Harry Potter and the Order of the Phoenix       J.K. Rowling
# 2                               To Kill a Mockingbird         Harper Lee
# 3                                 Pride and Prejudice        Jane Austen
# 4                                            Twilight    Stephenie Meyer
# 5                                      The Book Thief       Markus Zusak
# 6                            The Chronicles of Narnia         C.S. Lewis
# 7                                         Animal Farm      George Orwell
# 8   J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...     J.R.R. Tolkien
# 9                                  Gone with the Wind  Margaret Mitchell
# 10                             The Fault in Our Stars         John Green
# 11               The Hitchhiker's Guide to the Galaxy      Douglas Adams
# ...

# %%
df.tail(20)
# Out:
#                                              Title  \
# 52296                             Só o Amor é Real
# 52297                        O Mar que a Gente Faz
# 52298  Quanto Mais Depressa Ando, Mais Pequena Sou
# 52299             História Trágica com Final Feliz
# 52300                   Metamorfose à Beira do Céu
# 52301                          Amor em Segunda Mão
# 52302                               Errar é Divino
# 52303                          Cemitério de Pianos
# 52304                                        Livro
# 52305                    O Teu Rosto Será o Último
# 52306                         Planície de Espelhos
# 52307                                 Os Malaquias
# 52308                               A Alma Trocada
# 52309                          Os Anjos de Gabriel
# 52310   Insight: Case Files from the Psychic World
# 52311                   Past Lives, Future Healing
# 52312       Escuta o Teu Corpo: O Teu Melhor Amigo
# ...
