# %%
import pandas as pd

# %%
df = pd.read_csv("best_books_titles.csv")

print(df.shape)

df.head()
# Out:
# (52316, 3)
#                                                Title           Author  \
# 0            The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1  Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 2                              To Kill a Mockingbird       Harper Lee
# 3                                Pride and Prejudice      Jane Austen
# 4                            Twilight (Twilight, #1)  Stephenie Meyer
#
#                                 Rating
# 0  4.33 avg rating — 6,187,344 ratings
# 1  4.50 avg rating — 2,411,676 ratings
# 2  4.28 avg rating — 4,345,348 ratings
# 3  4.26 avg rating — 2,884,006 ratings
# 4  3.59 avg rating — 4,812,265 ratings

# %%
df.isnull().sum()
# Out:
# Title     98
# Author    98
# Rating    98
# dtype: int64

# %%
df[df.Title.isna()]
# Out:
#     Title Author Rating
# 102   NaN    NaN    NaN
# 103   NaN    NaN    NaN
# 104   NaN    NaN    NaN
# 105   NaN    NaN    NaN
# 106   NaN    NaN    NaN
# ..    ...    ...    ...
# 195   NaN    NaN    NaN
# 196   NaN    NaN    NaN
# 197   NaN    NaN    NaN
# 198   NaN    NaN    NaN
# 199   NaN    NaN    NaN
#
# [98 rows x 3 columns]

# %%
missing = pd.read_csv("best_books_titles_missing.csv")

print(missing.shape)

missing.head()
# Out:
# (100, 3)
#                                                Title  \
# 0                            Moby-Dick or, the Whale
# 1                                       The Red Tent
# 2                            The Secret Life of Bees
# 3  Harry Potter and the Goblet of Fire (Harry Pot...
# 4         Clockwork Angel (The Infernal Devices, #1)
#
#                                Author                               Rating
# 0                     Herman Melville    3.50 avg rating — 468,904 ratings
# 1    Anita Diamant (Goodreads Author)    4.18 avg rating — 509,505 ratings
# 2    Sue Monk Kidd (Goodreads Author)  4.05 avg rating — 1,094,700 ratings
# 3                        J.K. Rowling  4.56 avg rating — 2,489,931 ratings
# 4  Cassandra Clare (Goodreads Author)    4.33 avg rating — 636,982 ratings

# %%
df.query("Title == 'Moby-Dick or, the Whale'")
# Out:
#                        Title           Author  \
# 100  Moby-Dick or, the Whale  Herman Melville
#
#                                 Rating
# 100  3.50 avg rating — 468,894 ratings

# %%
df.iloc[101:120]
# Out:
#             Title                            Author  \
# 101  The Red Tent  Anita Diamant (Goodreads Author)
# 102           NaN                               NaN
# 103           NaN                               NaN
# 104           NaN                               NaN
# 105           NaN                               NaN
# 106           NaN                               NaN
# 107           NaN                               NaN
# 108           NaN                               NaN
# 109           NaN                               NaN
# 110           NaN                               NaN
# 111           NaN                               NaN
# 112           NaN                               NaN
# 113           NaN                               NaN
# 114           NaN                               NaN
# 115           NaN                               NaN
# 116           NaN                               NaN
# 117           NaN                               NaN
# ...

# %%
missing = missing.iloc[2:]

# %%
first = df.iloc[:102]

last = df.iloc[200:]

# %%
full_df = pd.concat([first, missing, last])

print(full_df.shape)

full_df.head()
# Out:
# (52316, 3)
#                                                Title           Author  \
# 0            The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1  Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 2                              To Kill a Mockingbird       Harper Lee
# 3                                Pride and Prejudice      Jane Austen
# 4                            Twilight (Twilight, #1)  Stephenie Meyer
#
#                                 Rating
# 0  4.33 avg rating — 6,187,344 ratings
# 1  4.50 avg rating — 2,411,676 ratings
# 2  4.28 avg rating — 4,345,348 ratings
# 3  4.26 avg rating — 2,884,006 ratings
# 4  3.59 avg rating — 4,812,265 ratings

# %%
full_df.isnull().sum()
# Out:
# Title     0
# Author    0
# Rating    0
# dtype: int64

# %%
full_df.iloc[105:139]
# Out:
#                                                 Title  \
# 5                            And Then There Were None
# 6                                           Middlesex
# 7   Harry Potter and the Half-Blood Prince (Harry ...
# 8                                        The Stranger
# 9                            The Master and Margarita
# 10  The Name of the Wind (The Kingkiller Chronicle...
# 11                                        The Shining
# 12                       The Adventures of Tom Sawyer
# 13                 Eragon (The Inheritance Cycle, #1)
# 14  Charlie and the Chocolate Factory (Charlie Buc...
# 15                                        On the Road
# 16                               Flowers For Algernon
# 17                                  The Metamorphosis
# 18                                 Looking for Alaska
# 19  The Shadow of the Wind (The Cemetery of Forgot...
# 20  The Curious Incident of the Dog in the Night-Time
# ...

# %%
full_df.dtypes
# Out:
# Title     object
# Author    object
# Rating    object
# dtype: object

# %%
full_df.isnull().sum()
# Out:
# Title     0
# Author    0
# Rating    0
# dtype: int64

# %%
def drop_parens(text):
    return text.split('(')[0].strip()

drop_parens('Patrick Rothfuss (Goodreads Author)')
# Out:
# 'Patrick Rothfuss'

# %%
for col in ['Title', 'Author']:
    full_df[col] = full_df[col].apply(drop_parens)

# %%
full_df.head()
# Out:
#                                        Title           Author  \
# 0                           The Hunger Games  Suzanne Collins
# 1  Harry Potter and the Order of the Phoenix     J.K. Rowling
# 2                      To Kill a Mockingbird       Harper Lee
# 3                        Pride and Prejudice      Jane Austen
# 4                                   Twilight  Stephenie Meyer
#
#                                 Rating
# 0  4.33 avg rating — 6,187,344 ratings
# 1  4.50 avg rating — 2,411,676 ratings
# 2  4.28 avg rating — 4,345,348 ratings
# 3  4.26 avg rating — 2,884,006 ratings
# 4  3.59 avg rating — 4,812,265 ratings

# %%
full_df['Rating'] = full_df['Rating'].apply(lambda x: x.split()[0])

# %%
full_df.head()
# Out:
#                                        Title           Author Rating
# 0                           The Hunger Games  Suzanne Collins   4.33
# 1  Harry Potter and the Order of the Phoenix     J.K. Rowling   4.50
# 2                      To Kill a Mockingbird       Harper Lee   4.28
# 3                        Pride and Prejudice      Jane Austen   4.26
# 4                                   Twilight  Stephenie Meyer   3.59

# %%
full_df.to_csv("cleaned_book_titles.csv", index=False)

# %% [markdown]
# ## Break
#
# Below here is exploratory work and no longer relevant.
#
# Below I discovered what was wrong with my first attempt at collecting the data

# %%
import csv

books = []
with open("best_books_titles.csv") as f:
    title = csv.reader(f)
    counter = 0
    for t in title:
        if counter % 2 == 0:
            books.append(t)
        counter += 1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-89af828aa45d> in <module>
#       5     title = csv.reader(f)
#       6     counter = 0
# ----> 7     for t in title:
#       8         if counter % 2 == 0:
#       9             books.append(t)
#
# ~\anaconda3\envs\books-kernel\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 6126: character maps to <undefined>

# %%
len(books)
# Out:
# 62

# %%
import pandas as pd

# %%
df = pd.read_csv("best_books_titles.csv", sep=',')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-407a80c9d6e3> in <module>
# ----> 1 df = pd.read_csv("best_books_titles.csv", sep=',')
#
# ~\anaconda3\envs\books-kernel\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
print(df.shape)
# Out:
# (52300, 1)

# %%
df.head()
# Out:
#                                  Title,Author,Rating
# 0  The Hunger Games (The Hunger Games, #1),by Suz...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  To Kill a Mockingbird,by Harper Lee,"4.28 avg ...
# 3  Pride and Prejudice,by Jane Austen,"4.26 avg r...
# 4  Twilight (Twilight, #1),by Stephenie Meyer,"3....
